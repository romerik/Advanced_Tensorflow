# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 980us/sample - loss: 237.5595 - y1_output_loss: 111.1884 - y2_output_loss: 124.8660 - y1_output_root_mean_squared_error: 10.5842 - y2_output_root_mean_squared_error: 11.2042 - val_loss: 43.0053 - val_y1_output_loss: 15.9921 - val_y2_output_loss: 28.2494 - val_y1_output_root_mean_squared_error: 3.9952 - val_y2_output_root_mean_squared_error: 5.2003
# Epoch 2/500
# 614/614 [==============================] - 0s 142us/sample - loss: 32.6586 - y1_output_loss: 12.7576 - y2_output_loss: 19.9282 - y1_output_root_mean_squared_error: 3.5579 - y2_output_root_mean_squared_error: 4.4722 - val_loss: 24.8465 - val_y1_output_loss: 12.2312 - val_y2_output_loss: 12.3048 - val_y1_output_root_mean_squared_error: 3.5374 - val_y2_output_root_mean_squared_error: 3.5118
# Epoch 3/500
# 614/614 [==============================] - 0s 134us/sample - loss: 27.1458 - y1_output_loss: 10.7666 - y2_output_loss: 16.3937 - y1_output_root_mean_squared_error: 3.2670 - y2_output_root_mean_squared_error: 4.0587 - val_loss: 30.9188 - val_y1_output_loss: 12.1438 - val_y2_output_loss: 18.7170 - val_y1_output_root_mean_squared_error: 3.5325 - val_y2_output_root_mean_squared_error: 4.2942
# Epoch 4/500
# 614/614 [==============================] - 0s 128us/sample - loss: 23.3187 - y1_output_loss: 9.5061 - y2_output_loss: 13.6760 - y1_output_root_mean_squared_error: 3.0916 - y2_output_root_mean_squared_error: 3.7096 - val_loss: 18.6517 - val_y1_output_loss: 8.4314 - val_y2_output_loss: 9.9135 - val_y1_output_root_mean_squared_error: 2.9515 - val_y2_output_root_mean_squared_error: 3.1528
# Epoch 5/500
# 614/614 [==============================] - 0s 132us/sample - loss: 21.3292 - y1_output_loss: 8.8671 - y2_output_loss: 12.4846 - y1_output_root_mean_squared_error: 2.9654 - y2_output_root_mean_squared_error: 3.5405 - val_loss: 47.4742 - val_y1_output_loss: 16.7535 - val_y2_output_loss: 31.3936 - val_y1_output_root_mean_squared_error: 4.1117 - val_y2_output_root_mean_squared_error: 5.5288
# Epoch 6/500
# 614/614 [==============================] - 0s 135us/sample - loss: 24.7379 - y1_output_loss: 9.4028 - y2_output_loss: 15.9499 - y1_output_root_mean_squared_error: 3.0514 - y2_output_root_mean_squared_error: 3.9277 - val_loss: 92.3391 - val_y1_output_loss: 17.2304 - val_y2_output_loss: 75.3644 - val_y1_output_root_mean_squared_error: 4.1574 - val_y2_output_root_mean_squared_error: 8.6634
# Epoch 7/500
# 614/614 [==============================] - 0s 131us/sample - loss: 26.2150 - y1_output_loss: 9.3790 - y2_output_loss: 16.6172 - y1_output_root_mean_squared_error: 3.0772 - y2_output_root_mean_squared_error: 4.0922 - val_loss: 16.7865 - val_y1_output_loss: 7.4478 - val_y2_output_loss: 8.8498 - val_y1_output_root_mean_squared_error: 2.7816 - val_y2_output_root_mean_squared_error: 3.0082
# Epoch 8/500
# 614/614 [==============================] - 0s 133us/sample - loss: 23.5220 - y1_output_loss: 8.8766 - y2_output_loss: 14.4996 - y1_output_root_mean_squared_error: 2.9916 - y2_output_root_mean_squared_error: 3.8174 - val_loss: 18.2259 - val_y1_output_loss: 8.5695 - val_y2_output_loss: 9.1839 - val_y1_output_root_mean_squared_error: 2.9779 - val_y2_output_root_mean_squared_error: 3.0591
# Epoch 9/500
# 614/614 [==============================] - 0s 135us/sample - loss: 26.9901 - y1_output_loss: 9.7030 - y2_output_loss: 17.4412 - y1_output_root_mean_squared_error: 3.1155 - y2_output_root_mean_squared_error: 4.1574 - val_loss: 36.2738 - val_y1_output_loss: 9.7200 - val_y2_output_loss: 26.7349 - val_y1_output_root_mean_squared_error: 3.1220 - val_y2_output_root_mean_squared_error: 5.1504
# Epoch 10/500
# 614/614 [==============================] - 0s 133us/sample - loss: 20.5884 - y1_output_loss: 8.1726 - y2_output_loss: 12.4894 - y1_output_root_mean_squared_error: 2.8561 - y2_output_root_mean_squared_error: 3.5258 - val_loss: 18.3307 - val_y1_output_loss: 7.8578 - val_y2_output_loss: 10.1276 - val_y1_output_root_mean_squared_error: 2.8402 - val_y2_output_root_mean_squared_error: 3.2038
# Epoch 11/500
# 614/614 [==============================] - 0s 136us/sample - loss: 22.9441 - y1_output_loss: 8.4125 - y2_output_loss: 14.6729 - y1_output_root_mean_squared_error: 2.8766 - y2_output_root_mean_squared_error: 3.8300 - val_loss: 48.5909 - val_y1_output_loss: 16.9378 - val_y2_output_loss: 32.9543 - val_y1_output_root_mean_squared_error: 4.1024 - val_y2_output_root_mean_squared_error: 5.6357
# Epoch 12/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.8851 - y1_output_loss: 7.5776 - y2_output_loss: 13.1352 - y1_output_root_mean_squared_error: 2.7617 - y2_output_root_mean_squared_error: 3.6412 - val_loss: 16.0212 - val_y1_output_loss: 7.3702 - val_y2_output_loss: 8.2859 - val_y1_output_root_mean_squared_error: 2.7594 - val_y2_output_root_mean_squared_error: 2.8994
# Epoch 13/500
# 614/614 [==============================] - 0s 132us/sample - loss: 23.7450 - y1_output_loss: 8.4067 - y2_output_loss: 15.5944 - y1_output_root_mean_squared_error: 2.8784 - y2_output_root_mean_squared_error: 3.9319 - val_loss: 72.3839 - val_y1_output_loss: 19.9149 - val_y2_output_loss: 54.6174 - val_y1_output_root_mean_squared_error: 4.4381 - val_y2_output_root_mean_squared_error: 7.2586
# Epoch 14/500
# 614/614 [==============================] - 0s 131us/sample - loss: 19.0308 - y1_output_loss: 6.9023 - y2_output_loss: 12.0419 - y1_output_root_mean_squared_error: 2.6361 - y2_output_root_mean_squared_error: 3.4759 - val_loss: 13.1643 - val_y1_output_loss: 5.5974 - val_y2_output_loss: 7.2205 - val_y1_output_root_mean_squared_error: 2.4096 - val_y2_output_root_mean_squared_error: 2.7126
# Epoch 15/500
# 614/614 [==============================] - 0s 127us/sample - loss: 15.0410 - y1_output_loss: 5.8880 - y2_output_loss: 9.0870 - y1_output_root_mean_squared_error: 2.4360 - y2_output_root_mean_squared_error: 3.0178 - val_loss: 17.3801 - val_y1_output_loss: 6.5606 - val_y2_output_loss: 10.4170 - val_y1_output_root_mean_squared_error: 2.6023 - val_y2_output_root_mean_squared_error: 3.2570
# Epoch 16/500
# 614/614 [==============================] - 0s 131us/sample - loss: 17.8612 - y1_output_loss: 6.7578 - y2_output_loss: 10.9894 - y1_output_root_mean_squared_error: 2.6023 - y2_output_root_mean_squared_error: 3.3301 - val_loss: 14.2441 - val_y1_output_loss: 7.0191 - val_y2_output_loss: 6.9030 - val_y1_output_root_mean_squared_error: 2.6890 - val_y2_output_root_mean_squared_error: 2.6483
# Epoch 17/500
# 614/614 [==============================] - 0s 128us/sample - loss: 17.4212 - y1_output_loss: 6.5357 - y2_output_loss: 10.9644 - y1_output_root_mean_squared_error: 2.5515 - y2_output_root_mean_squared_error: 3.3032 - val_loss: 11.8882 - val_y1_output_loss: 5.4457 - val_y2_output_loss: 6.3625 - val_y1_output_root_mean_squared_error: 2.3682 - val_y2_output_root_mean_squared_error: 2.5059
# Epoch 18/500
# 614/614 [==============================] - 0s 127us/sample - loss: 16.6659 - y1_output_loss: 6.1972 - y2_output_loss: 10.6200 - y1_output_root_mean_squared_error: 2.4671 - y2_output_root_mean_squared_error: 3.2526 - val_loss: 57.9058 - val_y1_output_loss: 18.7005 - val_y2_output_loss: 41.2048 - val_y1_output_root_mean_squared_error: 4.2924 - val_y2_output_root_mean_squared_error: 6.2834
# Epoch 19/500
# 614/614 [==============================] - 0s 158us/sample - loss: 15.2771 - y1_output_loss: 5.8176 - y2_output_loss: 9.4580 - y1_output_root_mean_squared_error: 2.4077 - y2_output_root_mean_squared_error: 3.0790 - val_loss: 22.3149 - val_y1_output_loss: 6.4939 - val_y2_output_loss: 16.5509 - val_y1_output_root_mean_squared_error: 2.5660 - val_y2_output_root_mean_squared_error: 3.9662
# Epoch 20/500
# 614/614 [==============================] - 0s 128us/sample - loss: 14.9764 - y1_output_loss: 5.3682 - y2_output_loss: 9.4974 - y1_output_root_mean_squared_error: 2.3255 - y2_output_root_mean_squared_error: 3.0933 - val_loss: 12.7377 - val_y1_output_loss: 5.2754 - val_y2_output_loss: 7.7865 - val_y1_output_root_mean_squared_error: 2.3173 - val_y2_output_root_mean_squared_error: 2.7144
# Epoch 21/500
# 614/614 [==============================] - 0s 125us/sample - loss: 15.1809 - y1_output_loss: 5.5997 - y2_output_loss: 9.9279 - y1_output_root_mean_squared_error: 2.3463 - y2_output_root_mean_squared_error: 3.1106 - val_loss: 28.7263 - val_y1_output_loss: 6.2618 - val_y2_output_loss: 23.4696 - val_y1_output_root_mean_squared_error: 2.5165 - val_y2_output_root_mean_squared_error: 4.7322
# Epoch 22/500
# 614/614 [==============================] - 0s 130us/sample - loss: 16.7014 - y1_output_loss: 5.6349 - y2_output_loss: 11.0024 - y1_output_root_mean_squared_error: 2.3683 - y2_output_root_mean_squared_error: 3.3305 - val_loss: 15.1035 - val_y1_output_loss: 6.1800 - val_y2_output_loss: 9.4591 - val_y1_output_root_mean_squared_error: 2.4912 - val_y2_output_root_mean_squared_error: 2.9829
# Epoch 23/500
# 614/614 [==============================] - 0s 131us/sample - loss: 11.7521 - y1_output_loss: 4.3777 - y2_output_loss: 7.3384 - y1_output_root_mean_squared_error: 2.0961 - y2_output_root_mean_squared_error: 2.7126 - val_loss: 9.3973 - val_y1_output_loss: 4.1697 - val_y2_output_loss: 5.2747 - val_y1_output_root_mean_squared_error: 2.0700 - val_y2_output_root_mean_squared_error: 2.2611
# Epoch 24/500
# 614/614 [==============================] - 0s 130us/sample - loss: 13.2860 - y1_output_loss: 4.7246 - y2_output_loss: 8.4872 - y1_output_root_mean_squared_error: 2.1812 - y2_output_root_mean_squared_error: 2.9204 - val_loss: 11.2878 - val_y1_output_loss: 5.0091 - val_y2_output_loss: 6.2999 - val_y1_output_root_mean_squared_error: 2.2634 - val_y2_output_root_mean_squared_error: 2.4829
# Epoch 25/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.8555 - y1_output_loss: 3.9394 - y2_output_loss: 6.8313 - y1_output_root_mean_squared_error: 1.9923 - y2_output_root_mean_squared_error: 2.6242 - val_loss: 9.5651 - val_y1_output_loss: 4.2574 - val_y2_output_loss: 5.2303 - val_y1_output_root_mean_squared_error: 2.0935 - val_y2_output_root_mean_squared_error: 2.2765
# Epoch 26/500
# 614/614 [==============================] - 0s 132us/sample - loss: 14.2244 - y1_output_loss: 4.9748 - y2_output_loss: 9.3439 - y1_output_root_mean_squared_error: 2.2213 - y2_output_root_mean_squared_error: 3.0480 - val_loss: 30.6356 - val_y1_output_loss: 8.2124 - val_y2_output_loss: 23.8435 - val_y1_output_root_mean_squared_error: 2.8466 - val_y2_output_root_mean_squared_error: 4.7469
# Epoch 27/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.5013 - y1_output_loss: 4.0608 - y2_output_loss: 7.4557 - y1_output_root_mean_squared_error: 2.0158 - y2_output_root_mean_squared_error: 2.7272 - val_loss: 22.3052 - val_y1_output_loss: 5.7189 - val_y2_output_loss: 17.5186 - val_y1_output_root_mean_squared_error: 2.3951 - val_y2_output_root_mean_squared_error: 4.0705
# Epoch 28/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.0724 - y1_output_loss: 3.3638 - y2_output_loss: 5.6602 - y1_output_root_mean_squared_error: 1.8360 - y2_output_root_mean_squared_error: 2.3878 - val_loss: 9.1641 - val_y1_output_loss: 3.6448 - val_y2_output_loss: 5.7975 - val_y1_output_root_mean_squared_error: 1.9272 - val_y2_output_root_mean_squared_error: 2.3345
# Epoch 29/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.6375 - y1_output_loss: 3.5878 - y2_output_loss: 7.1034 - y1_output_root_mean_squared_error: 1.8985 - y2_output_root_mean_squared_error: 2.6520 - val_loss: 23.4972 - val_y1_output_loss: 8.0010 - val_y2_output_loss: 15.5970 - val_y1_output_root_mean_squared_error: 2.8146 - val_y2_output_root_mean_squared_error: 3.9465
# Epoch 30/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.8986 - y1_output_loss: 3.4092 - y2_output_loss: 6.4293 - y1_output_root_mean_squared_error: 1.8528 - y2_output_root_mean_squared_error: 2.5428 - val_loss: 19.2056 - val_y1_output_loss: 6.5037 - val_y2_output_loss: 12.3974 - val_y1_output_root_mean_squared_error: 2.5666 - val_y2_output_root_mean_squared_error: 3.5522
# Epoch 31/500
# 614/614 [==============================] - 0s 127us/sample - loss: 9.0738 - y1_output_loss: 2.9818 - y2_output_loss: 6.1831 - y1_output_root_mean_squared_error: 1.7166 - y2_output_root_mean_squared_error: 2.4753 - val_loss: 12.8818 - val_y1_output_loss: 4.3259 - val_y2_output_loss: 8.9738 - val_y1_output_root_mean_squared_error: 2.0931 - val_y2_output_root_mean_squared_error: 2.9156
# Epoch 32/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.3701 - y1_output_loss: 3.1679 - y2_output_loss: 6.1317 - y1_output_root_mean_squared_error: 1.7833 - y2_output_root_mean_squared_error: 2.4880 - val_loss: 9.7827 - val_y1_output_loss: 3.6401 - val_y2_output_loss: 6.5689 - val_y1_output_root_mean_squared_error: 1.9134 - val_y2_output_root_mean_squared_error: 2.4742
# Epoch 33/500
# 614/614 [==============================] - 0s 132us/sample - loss: 8.2801 - y1_output_loss: 2.7506 - y2_output_loss: 5.4624 - y1_output_root_mean_squared_error: 1.6640 - y2_output_root_mean_squared_error: 2.3476 - val_loss: 7.1967 - val_y1_output_loss: 2.9427 - val_y2_output_loss: 4.3195 - val_y1_output_root_mean_squared_error: 1.7353 - val_y2_output_root_mean_squared_error: 2.0459
# Epoch 34/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.9543 - y1_output_loss: 2.7184 - y2_output_loss: 5.2351 - y1_output_root_mean_squared_error: 1.6439 - y2_output_root_mean_squared_error: 2.2917 - val_loss: 7.1135 - val_y1_output_loss: 2.6604 - val_y2_output_loss: 4.6317 - val_y1_output_root_mean_squared_error: 1.6535 - val_y2_output_root_mean_squared_error: 2.0927
# Epoch 35/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.3494 - y1_output_loss: 2.5494 - y2_output_loss: 4.7435 - y1_output_root_mean_squared_error: 1.6019 - y2_output_root_mean_squared_error: 2.1871 - val_loss: 8.1074 - val_y1_output_loss: 2.7206 - val_y2_output_loss: 5.6961 - val_y1_output_root_mean_squared_error: 1.6653 - val_y2_output_root_mean_squared_error: 2.3096
# Epoch 36/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.3850 - y1_output_loss: 2.4638 - y2_output_loss: 4.8709 - y1_output_root_mean_squared_error: 1.5755 - y2_output_root_mean_squared_error: 2.2143 - val_loss: 6.4724 - val_y1_output_loss: 2.5970 - val_y2_output_loss: 4.0355 - val_y1_output_root_mean_squared_error: 1.6215 - val_y2_output_root_mean_squared_error: 1.9604
# Epoch 37/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.2339 - y1_output_loss: 2.1855 - y2_output_loss: 5.0067 - y1_output_root_mean_squared_error: 1.4850 - y2_output_root_mean_squared_error: 2.2424 - val_loss: 8.1514 - val_y1_output_loss: 2.8333 - val_y2_output_loss: 5.3768 - val_y1_output_root_mean_squared_error: 1.6834 - val_y2_output_root_mean_squared_error: 2.3060
# Epoch 38/500
# 614/614 [==============================] - 0s 129us/sample - loss: 13.0450 - y1_output_loss: 4.3760 - y2_output_loss: 8.5682 - y1_output_root_mean_squared_error: 2.0998 - y2_output_root_mean_squared_error: 2.9387 - val_loss: 8.7817 - val_y1_output_loss: 3.8649 - val_y2_output_loss: 4.8008 - val_y1_output_root_mean_squared_error: 1.9935 - val_y2_output_root_mean_squared_error: 2.1926
# Epoch 39/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.5426 - y1_output_loss: 2.4277 - y2_output_loss: 5.2710 - y1_output_root_mean_squared_error: 1.5530 - y2_output_root_mean_squared_error: 2.2651 - val_loss: 6.4004 - val_y1_output_loss: 2.5892 - val_y2_output_loss: 4.0459 - val_y1_output_root_mean_squared_error: 1.6023 - val_y2_output_root_mean_squared_error: 1.9578
# Epoch 40/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.6334 - y1_output_loss: 2.1415 - y2_output_loss: 4.4482 - y1_output_root_mean_squared_error: 1.4680 - y2_output_root_mean_squared_error: 2.1162 - val_loss: 13.8147 - val_y1_output_loss: 5.0166 - val_y2_output_loss: 8.7079 - val_y1_output_root_mean_squared_error: 2.2428 - val_y2_output_root_mean_squared_error: 2.9639
# Epoch 41/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.4457 - y1_output_loss: 2.1886 - y2_output_loss: 4.3029 - y1_output_root_mean_squared_error: 1.4777 - y2_output_root_mean_squared_error: 2.0645 - val_loss: 6.6406 - val_y1_output_loss: 2.2780 - val_y2_output_loss: 4.3214 - val_y1_output_root_mean_squared_error: 1.5261 - val_y2_output_root_mean_squared_error: 2.0764
# Epoch 42/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.4286 - y1_output_loss: 2.4362 - y2_output_loss: 5.0735 - y1_output_root_mean_squared_error: 1.5463 - y2_output_root_mean_squared_error: 2.2445 - val_loss: 17.8617 - val_y1_output_loss: 4.5337 - val_y2_output_loss: 14.1874 - val_y1_output_root_mean_squared_error: 2.1182 - val_y2_output_root_mean_squared_error: 3.6572
# Epoch 43/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.7651 - y1_output_loss: 2.5900 - y2_output_loss: 5.2357 - y1_output_root_mean_squared_error: 1.6082 - y2_output_root_mean_squared_error: 2.2757 - val_loss: 16.3781 - val_y1_output_loss: 5.2987 - val_y2_output_loss: 11.0858 - val_y1_output_root_mean_squared_error: 2.2976 - val_y2_output_root_mean_squared_error: 3.3316
# Epoch 44/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.6263 - y1_output_loss: 3.2118 - y2_output_loss: 7.3533 - y1_output_root_mean_squared_error: 1.7976 - y2_output_root_mean_squared_error: 2.7194 - val_loss: 7.5952 - val_y1_output_loss: 2.2932 - val_y2_output_loss: 5.6757 - val_y1_output_root_mean_squared_error: 1.5178 - val_y2_output_root_mean_squared_error: 2.3003
# Epoch 45/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.5795 - y1_output_loss: 2.3517 - y2_output_loss: 5.1741 - y1_output_root_mean_squared_error: 1.5404 - y2_output_root_mean_squared_error: 2.2818 - val_loss: 4.9043 - val_y1_output_loss: 1.8268 - val_y2_output_loss: 3.1045 - val_y1_output_root_mean_squared_error: 1.3647 - val_y2_output_root_mean_squared_error: 1.7441
# Epoch 46/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.4153 - y1_output_loss: 2.0197 - y2_output_loss: 4.3614 - y1_output_root_mean_squared_error: 1.4241 - y2_output_root_mean_squared_error: 2.0946 - val_loss: 5.0951 - val_y1_output_loss: 1.8081 - val_y2_output_loss: 3.2724 - val_y1_output_root_mean_squared_error: 1.3603 - val_y2_output_root_mean_squared_error: 1.8013
# Epoch 47/500
# 614/614 [==============================] - 0s 129us/sample - loss: 7.0829 - y1_output_loss: 1.9415 - y2_output_loss: 5.1697 - y1_output_root_mean_squared_error: 1.3940 - y2_output_root_mean_squared_error: 2.2671 - val_loss: 6.8703 - val_y1_output_loss: 2.2018 - val_y2_output_loss: 4.6233 - val_y1_output_root_mean_squared_error: 1.4858 - val_y2_output_root_mean_squared_error: 2.1593
# Epoch 48/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.2514 - y1_output_loss: 1.9917 - y2_output_loss: 5.2004 - y1_output_root_mean_squared_error: 1.4174 - y2_output_root_mean_squared_error: 2.2896 - val_loss: 13.3417 - val_y1_output_loss: 2.9479 - val_y2_output_loss: 10.1972 - val_y1_output_root_mean_squared_error: 1.7164 - val_y2_output_root_mean_squared_error: 3.2243
# Epoch 49/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.5948 - y1_output_loss: 1.8583 - y2_output_loss: 4.6997 - y1_output_root_mean_squared_error: 1.3618 - y2_output_root_mean_squared_error: 2.1772 - val_loss: 5.5394 - val_y1_output_loss: 1.9320 - val_y2_output_loss: 3.5968 - val_y1_output_root_mean_squared_error: 1.3949 - val_y2_output_root_mean_squared_error: 1.8957
# Epoch 50/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.8699 - y1_output_loss: 1.7318 - y2_output_loss: 4.1607 - y1_output_root_mean_squared_error: 1.3092 - y2_output_root_mean_squared_error: 2.0386 - val_loss: 4.7169 - val_y1_output_loss: 1.7433 - val_y2_output_loss: 3.1370 - val_y1_output_root_mean_squared_error: 1.3288 - val_y2_output_root_mean_squared_error: 1.7179
# Epoch 51/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.5263 - y1_output_loss: 1.5155 - y2_output_loss: 4.0594 - y1_output_root_mean_squared_error: 1.2315 - y2_output_root_mean_squared_error: 2.0024 - val_loss: 34.4628 - val_y1_output_loss: 5.2335 - val_y2_output_loss: 29.7054 - val_y1_output_root_mean_squared_error: 2.2447 - val_y2_output_root_mean_squared_error: 5.4244
# Epoch 52/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.6789 - y1_output_loss: 2.2877 - y2_output_loss: 5.3586 - y1_output_root_mean_squared_error: 1.5138 - y2_output_root_mean_squared_error: 2.3211 - val_loss: 7.5477 - val_y1_output_loss: 2.8823 - val_y2_output_loss: 4.9558 - val_y1_output_root_mean_squared_error: 1.7045 - val_y2_output_root_mean_squared_error: 2.1546
# Epoch 53/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.2400 - y1_output_loss: 1.7006 - y2_output_loss: 4.5313 - y1_output_root_mean_squared_error: 1.3036 - y2_output_root_mean_squared_error: 2.1309 - val_loss: 7.2499 - val_y1_output_loss: 2.3934 - val_y2_output_loss: 4.7578 - val_y1_output_root_mean_squared_error: 1.5480 - val_y2_output_root_mean_squared_error: 2.2031
# Epoch 54/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.8985 - y1_output_loss: 1.7883 - y2_output_loss: 4.1602 - y1_output_root_mean_squared_error: 1.3228 - y2_output_root_mean_squared_error: 2.0368 - val_loss: 27.1434 - val_y1_output_loss: 9.7865 - val_y2_output_loss: 18.6193 - val_y1_output_root_mean_squared_error: 3.0212 - val_y2_output_root_mean_squared_error: 4.2445
# Epoch 55/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.2779 - y1_output_loss: 1.5198 - y2_output_loss: 3.7345 - y1_output_root_mean_squared_error: 1.2299 - y2_output_root_mean_squared_error: 1.9404 - val_loss: 5.4210 - val_y1_output_loss: 1.9684 - val_y2_output_loss: 3.4461 - val_y1_output_root_mean_squared_error: 1.4014 - val_y2_output_root_mean_squared_error: 1.8594
# Epoch 56/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.9998 - y1_output_loss: 1.4830 - y2_output_loss: 3.5377 - y1_output_root_mean_squared_error: 1.2204 - y2_output_root_mean_squared_error: 1.8736 - val_loss: 3.8890 - val_y1_output_loss: 1.4112 - val_y2_output_loss: 2.5426 - val_y1_output_root_mean_squared_error: 1.1935 - val_y2_output_root_mean_squared_error: 1.5699
# Epoch 57/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.1162 - y1_output_loss: 1.4097 - y2_output_loss: 3.7119 - y1_output_root_mean_squared_error: 1.1904 - y2_output_root_mean_squared_error: 1.9233 - val_loss: 14.9313 - val_y1_output_loss: 1.7859 - val_y2_output_loss: 13.0339 - val_y1_output_root_mean_squared_error: 1.3346 - val_y2_output_root_mean_squared_error: 3.6263
# Epoch 58/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5367 - y1_output_loss: 1.2845 - y2_output_loss: 3.2644 - y1_output_root_mean_squared_error: 1.1373 - y2_output_root_mean_squared_error: 1.8009 - val_loss: 5.6176 - val_y1_output_loss: 1.5217 - val_y2_output_loss: 4.0499 - val_y1_output_root_mean_squared_error: 1.2339 - val_y2_output_root_mean_squared_error: 2.0236
# Epoch 59/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.8874 - y1_output_loss: 1.4929 - y2_output_loss: 3.3750 - y1_output_root_mean_squared_error: 1.2268 - y2_output_root_mean_squared_error: 1.8391 - val_loss: 4.8099 - val_y1_output_loss: 1.4031 - val_y2_output_loss: 3.4026 - val_y1_output_root_mean_squared_error: 1.1843 - val_y2_output_root_mean_squared_error: 1.8459
# Epoch 60/500
# 614/614 [==============================] - 0s 134us/sample - loss: 5.1622 - y1_output_loss: 1.5024 - y2_output_loss: 3.6326 - y1_output_root_mean_squared_error: 1.2257 - y2_output_root_mean_squared_error: 1.9131 - val_loss: 4.3906 - val_y1_output_loss: 1.5413 - val_y2_output_loss: 2.8247 - val_y1_output_root_mean_squared_error: 1.2385 - val_y2_output_root_mean_squared_error: 1.6902
# Epoch 61/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.2302 - y1_output_loss: 1.1543 - y2_output_loss: 3.0478 - y1_output_root_mean_squared_error: 1.0773 - y2_output_root_mean_squared_error: 1.7520 - val_loss: 9.8467 - val_y1_output_loss: 3.1858 - val_y2_output_loss: 7.1403 - val_y1_output_root_mean_squared_error: 1.7808 - val_y2_output_root_mean_squared_error: 2.5837
# Epoch 62/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.7317 - y1_output_loss: 1.5347 - y2_output_loss: 4.1966 - y1_output_root_mean_squared_error: 1.2403 - y2_output_root_mean_squared_error: 2.0478 - val_loss: 3.6726 - val_y1_output_loss: 1.0533 - val_y2_output_loss: 2.7581 - val_y1_output_root_mean_squared_error: 1.0383 - val_y2_output_root_mean_squared_error: 1.6108
# Epoch 63/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.9909 - y1_output_loss: 1.3582 - y2_output_loss: 3.7621 - y1_output_root_mean_squared_error: 1.1489 - y2_output_root_mean_squared_error: 1.9159 - val_loss: 34.0077 - val_y1_output_loss: 13.4354 - val_y2_output_loss: 21.9825 - val_y1_output_root_mean_squared_error: 3.6313 - val_y2_output_root_mean_squared_error: 4.5630
# Epoch 64/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.8499 - y1_output_loss: 2.2488 - y2_output_loss: 5.5338 - y1_output_root_mean_squared_error: 1.5063 - y2_output_root_mean_squared_error: 2.3624 - val_loss: 3.3454 - val_y1_output_loss: 1.1396 - val_y2_output_loss: 2.2912 - val_y1_output_root_mean_squared_error: 1.0752 - val_y2_output_root_mean_squared_error: 1.4797
# Epoch 65/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.2049 - y1_output_loss: 1.2388 - y2_output_loss: 2.9555 - y1_output_root_mean_squared_error: 1.1120 - y2_output_root_mean_squared_error: 1.7229 - val_loss: 4.6064 - val_y1_output_loss: 1.1155 - val_y2_output_loss: 3.6274 - val_y1_output_root_mean_squared_error: 1.0625 - val_y2_output_root_mean_squared_error: 1.8648
# Epoch 66/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.0850 - y1_output_loss: 0.9508 - y2_output_loss: 3.1864 - y1_output_root_mean_squared_error: 0.9746 - y2_output_root_mean_squared_error: 1.7706 - val_loss: 3.8408 - val_y1_output_loss: 1.1613 - val_y2_output_loss: 2.6732 - val_y1_output_root_mean_squared_error: 1.0769 - val_y2_output_root_mean_squared_error: 1.6374
# Epoch 67/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.6043 - y1_output_loss: 1.3966 - y2_output_loss: 4.2043 - y1_output_root_mean_squared_error: 1.1717 - y2_output_root_mean_squared_error: 2.0570 - val_loss: 5.8060 - val_y1_output_loss: 3.4386 - val_y2_output_loss: 2.4556 - val_y1_output_root_mean_squared_error: 1.8300 - val_y2_output_root_mean_squared_error: 1.5675
# Epoch 68/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.5675 - y1_output_loss: 1.1296 - y2_output_loss: 3.5780 - y1_output_root_mean_squared_error: 1.0610 - y2_output_root_mean_squared_error: 1.8552 - val_loss: 26.5345 - val_y1_output_loss: 6.9485 - val_y2_output_loss: 20.9160 - val_y1_output_root_mean_squared_error: 2.6001 - val_y2_output_root_mean_squared_error: 4.4468
# Epoch 69/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6219 - y1_output_loss: 1.9204 - y2_output_loss: 4.6809 - y1_output_root_mean_squared_error: 1.3887 - y2_output_root_mean_squared_error: 2.1665 - val_loss: 5.5595 - val_y1_output_loss: 1.0439 - val_y2_output_loss: 4.8090 - val_y1_output_root_mean_squared_error: 1.0367 - val_y2_output_root_mean_squared_error: 2.1177
# Epoch 70/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.0434 - y1_output_loss: 1.0536 - y2_output_loss: 2.9597 - y1_output_root_mean_squared_error: 1.0283 - y2_output_root_mean_squared_error: 1.7280 - val_loss: 2.9713 - val_y1_output_loss: 0.7310 - val_y2_output_loss: 2.3583 - val_y1_output_root_mean_squared_error: 0.8641 - val_y2_output_root_mean_squared_error: 1.4915
# Epoch 71/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.0268 - y1_output_loss: 1.2957 - y2_output_loss: 3.7508 - y1_output_root_mean_squared_error: 1.1407 - y2_output_root_mean_squared_error: 1.9302 - val_loss: 3.8360 - val_y1_output_loss: 1.1613 - val_y2_output_loss: 2.6539 - val_y1_output_root_mean_squared_error: 1.0765 - val_y2_output_root_mean_squared_error: 1.6362
# Epoch 72/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.4874 - y1_output_loss: 0.8784 - y2_output_loss: 2.5940 - y1_output_root_mean_squared_error: 0.9335 - y2_output_root_mean_squared_error: 1.6174 - val_loss: 3.6431 - val_y1_output_loss: 1.2432 - val_y2_output_loss: 2.4772 - val_y1_output_root_mean_squared_error: 1.1113 - val_y2_output_root_mean_squared_error: 1.5519
# Epoch 73/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.8039 - y1_output_loss: 1.0516 - y2_output_loss: 2.7673 - y1_output_root_mean_squared_error: 1.0203 - y2_output_root_mean_squared_error: 1.6622 - val_loss: 6.8057 - val_y1_output_loss: 3.3231 - val_y2_output_loss: 3.5250 - val_y1_output_root_mean_squared_error: 1.7940 - val_y2_output_root_mean_squared_error: 1.8940
# Epoch 74/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7162 - y1_output_loss: 0.9221 - y2_output_loss: 2.7938 - y1_output_root_mean_squared_error: 0.9609 - y2_output_root_mean_squared_error: 1.6712 - val_loss: 3.8414 - val_y1_output_loss: 0.8659 - val_y2_output_loss: 3.1247 - val_y1_output_root_mean_squared_error: 0.9383 - val_y2_output_root_mean_squared_error: 1.7207
# Epoch 75/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3679 - y1_output_loss: 0.8348 - y2_output_loss: 2.5256 - y1_output_root_mean_squared_error: 0.9171 - y2_output_root_mean_squared_error: 1.5896 - val_loss: 3.5959 - val_y1_output_loss: 0.9045 - val_y2_output_loss: 2.5976 - val_y1_output_root_mean_squared_error: 0.9588 - val_y2_output_root_mean_squared_error: 1.6361
# Epoch 76/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.7047 - y1_output_loss: 0.9078 - y2_output_loss: 2.7702 - y1_output_root_mean_squared_error: 0.9549 - y2_output_root_mean_squared_error: 1.6712 - val_loss: 2.5902 - val_y1_output_loss: 0.7720 - val_y2_output_loss: 1.9094 - val_y1_output_root_mean_squared_error: 0.8742 - val_y2_output_root_mean_squared_error: 1.3513
# Epoch 77/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.0387 - y1_output_loss: 1.0069 - y2_output_loss: 2.9986 - y1_output_root_mean_squared_error: 1.0079 - y2_output_root_mean_squared_error: 1.7387 - val_loss: 2.6999 - val_y1_output_loss: 0.8304 - val_y2_output_loss: 1.9299 - val_y1_output_root_mean_squared_error: 0.9175 - val_y2_output_root_mean_squared_error: 1.3631
# Epoch 78/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0361 - y1_output_loss: 0.7848 - y2_output_loss: 2.2606 - y1_output_root_mean_squared_error: 0.8885 - y2_output_root_mean_squared_error: 1.4989 - val_loss: 5.7603 - val_y1_output_loss: 1.7280 - val_y2_output_loss: 4.0574 - val_y1_output_root_mean_squared_error: 1.2956 - val_y2_output_root_mean_squared_error: 2.0203
# Epoch 79/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.8835 - y1_output_loss: 0.7189 - y2_output_loss: 2.1489 - y1_output_root_mean_squared_error: 0.8509 - y2_output_root_mean_squared_error: 1.4695 - val_loss: 3.5768 - val_y1_output_loss: 1.0929 - val_y2_output_loss: 2.5809 - val_y1_output_root_mean_squared_error: 1.0555 - val_y2_output_root_mean_squared_error: 1.5693
# Epoch 80/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.9398 - y1_output_loss: 1.2466 - y2_output_loss: 3.6515 - y1_output_root_mean_squared_error: 1.1201 - y2_output_root_mean_squared_error: 1.9197 - val_loss: 3.0445 - val_y1_output_loss: 0.9565 - val_y2_output_loss: 2.0751 - val_y1_output_root_mean_squared_error: 0.9850 - val_y2_output_root_mean_squared_error: 1.4402
# Epoch 81/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.4358 - y1_output_loss: 1.1119 - y2_output_loss: 3.2903 - y1_output_root_mean_squared_error: 1.0582 - y2_output_root_mean_squared_error: 1.8210 - val_loss: 3.8347 - val_y1_output_loss: 0.8165 - val_y2_output_loss: 3.1302 - val_y1_output_root_mean_squared_error: 0.9180 - val_y2_output_root_mean_squared_error: 1.7297
# Epoch 82/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.9759 - y1_output_loss: 0.6750 - y2_output_loss: 2.2884 - y1_output_root_mean_squared_error: 0.8254 - y2_output_root_mean_squared_error: 1.5148 - val_loss: 2.4765 - val_y1_output_loss: 0.6183 - val_y2_output_loss: 1.8336 - val_y1_output_root_mean_squared_error: 0.7955 - val_y2_output_root_mean_squared_error: 1.3578
# Epoch 83/500
# 614/614 [==============================] - 0s 128us/sample - loss: 11.5085 - y1_output_loss: 3.6558 - y2_output_loss: 7.7609 - y1_output_root_mean_squared_error: 1.9171 - y2_output_root_mean_squared_error: 2.7988 - val_loss: 8.7934 - val_y1_output_loss: 2.3527 - val_y2_output_loss: 6.9541 - val_y1_output_root_mean_squared_error: 1.5100 - val_y2_output_root_mean_squared_error: 2.5521
# Epoch 84/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0803 - y1_output_loss: 0.8341 - y2_output_loss: 2.2287 - y1_output_root_mean_squared_error: 0.9118 - y2_output_root_mean_squared_error: 1.4996 - val_loss: 3.9148 - val_y1_output_loss: 1.4418 - val_y2_output_loss: 2.4586 - val_y1_output_root_mean_squared_error: 1.1831 - val_y2_output_root_mean_squared_error: 1.5859
# Epoch 85/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.1518 - y1_output_loss: 0.7115 - y2_output_loss: 2.4361 - y1_output_root_mean_squared_error: 0.8441 - y2_output_root_mean_squared_error: 1.5619 - val_loss: 2.4767 - val_y1_output_loss: 0.7446 - val_y2_output_loss: 1.7840 - val_y1_output_root_mean_squared_error: 0.8734 - val_y2_output_root_mean_squared_error: 1.3092
# Epoch 86/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.1094 - y1_output_loss: 0.7672 - y2_output_loss: 2.3572 - y1_output_root_mean_squared_error: 0.8731 - y2_output_root_mean_squared_error: 1.5320 - val_loss: 2.3082 - val_y1_output_loss: 0.6592 - val_y2_output_loss: 1.6658 - val_y1_output_root_mean_squared_error: 0.8153 - val_y2_output_root_mean_squared_error: 1.2820
# Epoch 87/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.4702 - y1_output_loss: 0.8782 - y2_output_loss: 2.5707 - y1_output_root_mean_squared_error: 0.9388 - y2_output_root_mean_squared_error: 1.6090 - val_loss: 3.6925 - val_y1_output_loss: 1.3989 - val_y2_output_loss: 2.4720 - val_y1_output_root_mean_squared_error: 1.1655 - val_y2_output_root_mean_squared_error: 1.5278
# Epoch 88/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.0764 - y1_output_loss: 0.7426 - y2_output_loss: 2.3625 - y1_output_root_mean_squared_error: 0.8626 - y2_output_root_mean_squared_error: 1.5272 - val_loss: 4.4430 - val_y1_output_loss: 0.8978 - val_y2_output_loss: 3.6975 - val_y1_output_root_mean_squared_error: 0.9547 - val_y2_output_root_mean_squared_error: 1.8792
# Epoch 89/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.2717 - y1_output_loss: 0.8143 - y2_output_loss: 2.4867 - y1_output_root_mean_squared_error: 0.8997 - y2_output_root_mean_squared_error: 1.5692 - val_loss: 5.1261 - val_y1_output_loss: 2.0233 - val_y2_output_loss: 3.2426 - val_y1_output_root_mean_squared_error: 1.3767 - val_y2_output_root_mean_squared_error: 1.7974
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.7427 - y1_output_loss: 0.6256 - y2_output_loss: 2.1975 - y1_output_root_mean_squared_error: 0.7928 - y2_output_root_mean_squared_error: 1.4540 - val_loss: 10.5867 - val_y1_output_loss: 0.9893 - val_y2_output_loss: 10.1858 - val_y1_output_root_mean_squared_error: 0.9662 - val_y2_output_root_mean_squared_error: 3.1070
# Epoch 91/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.0318 - y1_output_loss: 1.1828 - y2_output_loss: 3.8122 - y1_output_root_mean_squared_error: 1.0895 - y2_output_root_mean_squared_error: 1.9608 - val_loss: 2.1988 - val_y1_output_loss: 0.7308 - val_y2_output_loss: 1.4651 - val_y1_output_root_mean_squared_error: 0.8502 - val_y2_output_root_mean_squared_error: 1.2149
# Epoch 92/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.0039 - y1_output_loss: 0.7039 - y2_output_loss: 2.2797 - y1_output_root_mean_squared_error: 0.8382 - y2_output_root_mean_squared_error: 1.5170 - val_loss: 2.0508 - val_y1_output_loss: 0.5628 - val_y2_output_loss: 1.4660 - val_y1_output_root_mean_squared_error: 0.7519 - val_y2_output_root_mean_squared_error: 1.2188
# Epoch 93/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1615 - y1_output_loss: 0.6802 - y2_output_loss: 2.4874 - y1_output_root_mean_squared_error: 0.8246 - y2_output_root_mean_squared_error: 1.5753 - val_loss: 5.5135 - val_y1_output_loss: 0.7465 - val_y2_output_loss: 4.6817 - val_y1_output_root_mean_squared_error: 0.8655 - val_y2_output_root_mean_squared_error: 2.1827
# Epoch 94/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.7246 - y1_output_loss: 0.9115 - y2_output_loss: 2.7913 - y1_output_root_mean_squared_error: 0.9557 - y2_output_root_mean_squared_error: 1.6766 - val_loss: 2.4439 - val_y1_output_loss: 0.6671 - val_y2_output_loss: 1.7738 - val_y1_output_root_mean_squared_error: 0.8110 - val_y2_output_root_mean_squared_error: 1.3364
# Epoch 95/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.8579 - y1_output_loss: 0.6389 - y2_output_loss: 2.1985 - y1_output_root_mean_squared_error: 0.8026 - y2_output_root_mean_squared_error: 1.4879 - val_loss: 3.3119 - val_y1_output_loss: 0.8625 - val_y2_output_loss: 2.6337 - val_y1_output_root_mean_squared_error: 0.9145 - val_y2_output_root_mean_squared_error: 1.5734
# Epoch 96/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.8567 - y1_output_loss: 0.5656 - y2_output_loss: 2.2822 - y1_output_root_mean_squared_error: 0.7534 - y2_output_root_mean_squared_error: 1.5130 - val_loss: 3.7401 - val_y1_output_loss: 0.7489 - val_y2_output_loss: 3.1110 - val_y1_output_root_mean_squared_error: 0.8652 - val_y2_output_root_mean_squared_error: 1.7296
# Epoch 97/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.6946 - y1_output_loss: 0.6524 - y2_output_loss: 2.0594 - y1_output_root_mean_squared_error: 0.8081 - y2_output_root_mean_squared_error: 1.4288 - val_loss: 2.4421 - val_y1_output_loss: 0.7211 - val_y2_output_loss: 1.7870 - val_y1_output_root_mean_squared_error: 0.8423 - val_y2_output_root_mean_squared_error: 1.3163
# Epoch 98/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.7005 - y1_output_loss: 0.6910 - y2_output_loss: 1.9926 - y1_output_root_mean_squared_error: 0.8300 - y2_output_root_mean_squared_error: 1.4183 - val_loss: 2.4151 - val_y1_output_loss: 0.7569 - val_y2_output_loss: 1.6907 - val_y1_output_root_mean_squared_error: 0.8839 - val_y2_output_root_mean_squared_error: 1.2782
# Epoch 99/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.4125 - y1_output_loss: 0.5327 - y2_output_loss: 1.8594 - y1_output_root_mean_squared_error: 0.7320 - y2_output_root_mean_squared_error: 1.3699 - val_loss: 1.9904 - val_y1_output_loss: 0.5007 - val_y2_output_loss: 1.5628 - val_y1_output_root_mean_squared_error: 0.7043 - val_y2_output_root_mean_squared_error: 1.2224
# Epoch 100/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3616 - y1_output_loss: 0.5046 - y2_output_loss: 1.8467 - y1_output_root_mean_squared_error: 0.7091 - y2_output_root_mean_squared_error: 1.3634 - val_loss: 3.3030 - val_y1_output_loss: 1.2871 - val_y2_output_loss: 2.1362 - val_y1_output_root_mean_squared_error: 1.1234 - val_y2_output_root_mean_squared_error: 1.4286
# Epoch 101/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0693 - y1_output_loss: 0.7617 - y2_output_loss: 2.3206 - y1_output_root_mean_squared_error: 0.8767 - y2_output_root_mean_squared_error: 1.5168 - val_loss: 4.3295 - val_y1_output_loss: 1.0056 - val_y2_output_loss: 3.3431 - val_y1_output_root_mean_squared_error: 0.9779 - val_y2_output_root_mean_squared_error: 1.8366
# Epoch 102/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5776 - y1_output_loss: 0.5993 - y2_output_loss: 1.9579 - y1_output_root_mean_squared_error: 0.7773 - y2_output_root_mean_squared_error: 1.4048 - val_loss: 2.9206 - val_y1_output_loss: 0.5242 - val_y2_output_loss: 2.4900 - val_y1_output_root_mean_squared_error: 0.7211 - val_y2_output_root_mean_squared_error: 1.5494
# Epoch 103/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.3595 - y1_output_loss: 0.5238 - y2_output_loss: 1.8137 - y1_output_root_mean_squared_error: 0.7269 - y2_output_root_mean_squared_error: 1.3532 - val_loss: 2.0805 - val_y1_output_loss: 0.5510 - val_y2_output_loss: 1.5063 - val_y1_output_root_mean_squared_error: 0.7425 - val_y2_output_root_mean_squared_error: 1.2366
# Epoch 104/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.2055 - y1_output_loss: 0.4697 - y2_output_loss: 1.7327 - y1_output_root_mean_squared_error: 0.6864 - y2_output_root_mean_squared_error: 1.3170 - val_loss: 2.0491 - val_y1_output_loss: 0.4723 - val_y2_output_loss: 1.5579 - val_y1_output_root_mean_squared_error: 0.6846 - val_y2_output_root_mean_squared_error: 1.2571
# Epoch 105/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5404 - y1_output_loss: 0.5738 - y2_output_loss: 1.9496 - y1_output_root_mean_squared_error: 0.7589 - y2_output_root_mean_squared_error: 1.4016 - val_loss: 2.7200 - val_y1_output_loss: 0.6465 - val_y2_output_loss: 2.0304 - val_y1_output_root_mean_squared_error: 0.7965 - val_y2_output_root_mean_squared_error: 1.4442
# Epoch 106/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.8797 - y1_output_loss: 0.6348 - y2_output_loss: 2.2375 - y1_output_root_mean_squared_error: 0.7987 - y2_output_root_mean_squared_error: 1.4973 - val_loss: 4.2546 - val_y1_output_loss: 0.5201 - val_y2_output_loss: 3.6434 - val_y1_output_root_mean_squared_error: 0.7133 - val_y2_output_root_mean_squared_error: 1.9354
# Epoch 107/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5645 - y1_output_loss: 0.6261 - y2_output_loss: 1.9532 - y1_output_root_mean_squared_error: 0.7938 - y2_output_root_mean_squared_error: 1.3908 - val_loss: 3.5857 - val_y1_output_loss: 0.7401 - val_y2_output_loss: 2.9930 - val_y1_output_root_mean_squared_error: 0.8581 - val_y2_output_root_mean_squared_error: 1.6880
# Epoch 108/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7050 - y1_output_loss: 0.6217 - y2_output_loss: 2.0706 - y1_output_root_mean_squared_error: 0.7875 - y2_output_root_mean_squared_error: 1.4439 - val_loss: 2.6042 - val_y1_output_loss: 0.7803 - val_y2_output_loss: 1.8130 - val_y1_output_root_mean_squared_error: 0.8636 - val_y2_output_root_mean_squared_error: 1.3632
# Epoch 109/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.6023 - y1_output_loss: 0.6021 - y2_output_loss: 1.9774 - y1_output_root_mean_squared_error: 0.7792 - y2_output_root_mean_squared_error: 1.4125 - val_loss: 3.3198 - val_y1_output_loss: 0.7842 - val_y2_output_loss: 2.6704 - val_y1_output_root_mean_squared_error: 0.8881 - val_y2_output_root_mean_squared_error: 1.5909
# Epoch 110/500
# 614/614 [==============================] - 0s 129us/sample - loss: 1.8561 - y1_output_loss: 0.4429 - y2_output_loss: 1.4108 - y1_output_root_mean_squared_error: 0.6623 - y2_output_root_mean_squared_error: 1.1906 - val_loss: 2.2040 - val_y1_output_loss: 0.7064 - val_y2_output_loss: 1.4931 - val_y1_output_root_mean_squared_error: 0.8514 - val_y2_output_root_mean_squared_error: 1.2162
# Epoch 111/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.5210 - y1_output_loss: 0.5407 - y2_output_loss: 1.9882 - y1_output_root_mean_squared_error: 0.7378 - y2_output_root_mean_squared_error: 1.4060 - val_loss: 5.2195 - val_y1_output_loss: 0.5647 - val_y2_output_loss: 4.5904 - val_y1_output_root_mean_squared_error: 0.7389 - val_y2_output_root_mean_squared_error: 2.1618
# Epoch 112/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5031 - y1_output_loss: 0.5833 - y2_output_loss: 1.9045 - y1_output_root_mean_squared_error: 0.7647 - y2_output_root_mean_squared_error: 1.3851 - val_loss: 3.5503 - val_y1_output_loss: 1.3703 - val_y2_output_loss: 2.3014 - val_y1_output_root_mean_squared_error: 1.1617 - val_y2_output_root_mean_squared_error: 1.4835
# Epoch 113/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.2438 - y1_output_loss: 0.4700 - y2_output_loss: 1.7654 - y1_output_root_mean_squared_error: 0.6884 - y2_output_root_mean_squared_error: 1.3304 - val_loss: 4.1771 - val_y1_output_loss: 1.1168 - val_y2_output_loss: 3.1751 - val_y1_output_root_mean_squared_error: 1.0580 - val_y2_output_root_mean_squared_error: 1.7486
# Epoch 114/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.9810 - y1_output_loss: 0.7149 - y2_output_loss: 2.2507 - y1_output_root_mean_squared_error: 0.8489 - y2_output_root_mean_squared_error: 1.5035 - val_loss: 1.9629 - val_y1_output_loss: 0.4635 - val_y2_output_loss: 1.5630 - val_y1_output_root_mean_squared_error: 0.6615 - val_y2_output_root_mean_squared_error: 1.2351
# Epoch 115/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.4898 - y1_output_loss: 1.0078 - y2_output_loss: 3.4420 - y1_output_root_mean_squared_error: 1.0087 - y2_output_root_mean_squared_error: 1.8634 - val_loss: 2.0848 - val_y1_output_loss: 0.4807 - val_y2_output_loss: 1.6299 - val_y1_output_root_mean_squared_error: 0.6874 - val_y2_output_root_mean_squared_error: 1.2698
# Epoch 116/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.1197 - y1_output_loss: 0.6946 - y2_output_loss: 2.4601 - y1_output_root_mean_squared_error: 0.8355 - y2_output_root_mean_squared_error: 1.5562 - val_loss: 7.4519 - val_y1_output_loss: 0.6399 - val_y2_output_loss: 7.0637 - val_y1_output_root_mean_squared_error: 0.7942 - val_y2_output_root_mean_squared_error: 2.6117
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.9130 - y1_output_loss: 0.4243 - y2_output_loss: 1.4766 - y1_output_root_mean_squared_error: 0.6526 - y2_output_root_mean_squared_error: 1.2195 - val_loss: 2.4496 - val_y1_output_loss: 0.8378 - val_y2_output_loss: 1.5875 - val_y1_output_root_mean_squared_error: 0.8970 - val_y2_output_root_mean_squared_error: 1.2826
# Epoch 118/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.4216 - y1_output_loss: 0.6206 - y2_output_loss: 1.7840 - y1_output_root_mean_squared_error: 0.7902 - y2_output_root_mean_squared_error: 1.3406 - val_loss: 2.0126 - val_y1_output_loss: 0.3785 - val_y2_output_loss: 1.6863 - val_y1_output_root_mean_squared_error: 0.6141 - val_y2_output_root_mean_squared_error: 1.2789
# Epoch 119/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6278 - y1_output_loss: 0.5250 - y2_output_loss: 2.1747 - y1_output_root_mean_squared_error: 0.7276 - y2_output_root_mean_squared_error: 1.4486 - val_loss: 9.3361 - val_y1_output_loss: 1.2507 - val_y2_output_loss: 8.0620 - val_y1_output_root_mean_squared_error: 1.0935 - val_y2_output_root_mean_squared_error: 2.8531
# Epoch 120/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.8250 - y1_output_loss: 0.5668 - y2_output_loss: 2.2626 - y1_output_root_mean_squared_error: 0.7545 - y2_output_root_mean_squared_error: 1.5019 - val_loss: 2.5107 - val_y1_output_loss: 0.4644 - val_y2_output_loss: 1.9848 - val_y1_output_root_mean_squared_error: 0.6729 - val_y2_output_root_mean_squared_error: 1.4346
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4395 - y1_output_loss: 0.1303 - y2_output_loss: 0.3111 - y1_output_root_mean_squared_error: 0.3595 - y2_output_root_mean_squared_error: 0.5570 - val_loss: 0.7597 - val_y1_output_loss: 0.1879 - val_y2_output_loss: 0.6001 - val_y1_output_root_mean_squared_error: 0.4337 - val_y2_output_root_mean_squared_error: 0.7561
# Epoch 462/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4268 - y1_output_loss: 0.1243 - y2_output_loss: 0.3004 - y1_output_root_mean_squared_error: 0.3533 - y2_output_root_mean_squared_error: 0.5495 - val_loss: 0.6074 - val_y1_output_loss: 0.1481 - val_y2_output_loss: 0.4967 - val_y1_output_root_mean_squared_error: 0.3905 - val_y2_output_root_mean_squared_error: 0.6744
# Epoch 463/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3351 - y1_output_loss: 0.1088 - y2_output_loss: 0.2289 - y1_output_root_mean_squared_error: 0.3267 - y2_output_root_mean_squared_error: 0.4778 - val_loss: 0.7689 - val_y1_output_loss: 0.2086 - val_y2_output_loss: 0.5666 - val_y1_output_root_mean_squared_error: 0.4630 - val_y2_output_root_mean_squared_error: 0.7447
# Epoch 464/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5999 - y1_output_loss: 0.1526 - y2_output_loss: 0.4503 - y1_output_root_mean_squared_error: 0.3909 - y2_output_root_mean_squared_error: 0.6687 - val_loss: 2.0074 - val_y1_output_loss: 0.5061 - val_y2_output_loss: 1.4781 - val_y1_output_root_mean_squared_error: 0.7093 - val_y2_output_root_mean_squared_error: 1.2265
# Epoch 465/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4442 - y1_output_loss: 0.1368 - y2_output_loss: 0.3053 - y1_output_root_mean_squared_error: 0.3705 - y2_output_root_mean_squared_error: 0.5540 - val_loss: 0.8534 - val_y1_output_loss: 0.2142 - val_y2_output_loss: 0.6265 - val_y1_output_root_mean_squared_error: 0.4696 - val_y2_output_root_mean_squared_error: 0.7956
# Epoch 466/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3692 - y1_output_loss: 0.1023 - y2_output_loss: 0.2665 - y1_output_root_mean_squared_error: 0.3203 - y2_output_root_mean_squared_error: 0.5164 - val_loss: 0.8852 - val_y1_output_loss: 0.2169 - val_y2_output_loss: 0.7280 - val_y1_output_root_mean_squared_error: 0.4646 - val_y2_output_root_mean_squared_error: 0.8181
# Epoch 467/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3709 - y1_output_loss: 0.1257 - y2_output_loss: 0.2425 - y1_output_root_mean_squared_error: 0.3558 - y2_output_root_mean_squared_error: 0.4943 - val_loss: 0.7009 - val_y1_output_loss: 0.1461 - val_y2_output_loss: 0.5937 - val_y1_output_root_mean_squared_error: 0.3841 - val_y2_output_root_mean_squared_error: 0.7438
# Epoch 468/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.5392 - y1_output_loss: 0.1732 - y2_output_loss: 0.3633 - y1_output_root_mean_squared_error: 0.4167 - y2_output_root_mean_squared_error: 0.6046 - val_loss: 0.7356 - val_y1_output_loss: 0.1760 - val_y2_output_loss: 0.5518 - val_y1_output_root_mean_squared_error: 0.4253 - val_y2_output_root_mean_squared_error: 0.7448
# Epoch 469/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3162 - y1_output_loss: 0.1060 - y2_output_loss: 0.2076 - y1_output_root_mean_squared_error: 0.3270 - y2_output_root_mean_squared_error: 0.4575 - val_loss: 0.7255 - val_y1_output_loss: 0.1584 - val_y2_output_loss: 0.6205 - val_y1_output_root_mean_squared_error: 0.3966 - val_y2_output_root_mean_squared_error: 0.7538
# Epoch 470/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3677 - y1_output_loss: 0.1138 - y2_output_loss: 0.2561 - y1_output_root_mean_squared_error: 0.3347 - y2_output_root_mean_squared_error: 0.5056 - val_loss: 0.8797 - val_y1_output_loss: 0.2113 - val_y2_output_loss: 0.7118 - val_y1_output_root_mean_squared_error: 0.4589 - val_y2_output_root_mean_squared_error: 0.8180
# Epoch 471/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3133 - y1_output_loss: 0.1078 - y2_output_loss: 0.2042 - y1_output_root_mean_squared_error: 0.3280 - y2_output_root_mean_squared_error: 0.4535 - val_loss: 0.6123 - val_y1_output_loss: 0.1777 - val_y2_output_loss: 0.4561 - val_y1_output_root_mean_squared_error: 0.4244 - val_y2_output_root_mean_squared_error: 0.6574
# Epoch 472/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3500 - y1_output_loss: 0.1161 - y2_output_loss: 0.2332 - y1_output_root_mean_squared_error: 0.3423 - y2_output_root_mean_squared_error: 0.4825 - val_loss: 0.7425 - val_y1_output_loss: 0.1651 - val_y2_output_loss: 0.5803 - val_y1_output_root_mean_squared_error: 0.4129 - val_y2_output_root_mean_squared_error: 0.7563
# Epoch 473/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3984 - y1_output_loss: 0.1319 - y2_output_loss: 0.2686 - y1_output_root_mean_squared_error: 0.3640 - y2_output_root_mean_squared_error: 0.5157 - val_loss: 0.8342 - val_y1_output_loss: 0.2245 - val_y2_output_loss: 0.6840 - val_y1_output_root_mean_squared_error: 0.4654 - val_y2_output_root_mean_squared_error: 0.7858
# Epoch 474/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4440 - y1_output_loss: 0.1267 - y2_output_loss: 0.3181 - y1_output_root_mean_squared_error: 0.3571 - y2_output_root_mean_squared_error: 0.5626 - val_loss: 1.1456 - val_y1_output_loss: 0.1750 - val_y2_output_loss: 1.0384 - val_y1_output_root_mean_squared_error: 0.4203 - val_y2_output_root_mean_squared_error: 0.9843
# Epoch 475/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4771 - y1_output_loss: 0.1326 - y2_output_loss: 0.3408 - y1_output_root_mean_squared_error: 0.3655 - y2_output_root_mean_squared_error: 0.5861 - val_loss: 0.6643 - val_y1_output_loss: 0.1784 - val_y2_output_loss: 0.5061 - val_y1_output_root_mean_squared_error: 0.4273 - val_y2_output_root_mean_squared_error: 0.6941
# Epoch 476/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3435 - y1_output_loss: 0.1011 - y2_output_loss: 0.2507 - y1_output_root_mean_squared_error: 0.3160 - y2_output_root_mean_squared_error: 0.4936 - val_loss: 1.6827 - val_y1_output_loss: 0.1588 - val_y2_output_loss: 1.6270 - val_y1_output_root_mean_squared_error: 0.4045 - val_y2_output_root_mean_squared_error: 1.2325
# Epoch 477/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.9918 - y1_output_loss: 0.2785 - y2_output_loss: 0.7039 - y1_output_root_mean_squared_error: 0.5302 - y2_output_root_mean_squared_error: 0.8430 - val_loss: 0.6224 - val_y1_output_loss: 0.1609 - val_y2_output_loss: 0.4848 - val_y1_output_root_mean_squared_error: 0.4053 - val_y2_output_root_mean_squared_error: 0.6769
# Epoch 478/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3899 - y1_output_loss: 0.1125 - y2_output_loss: 0.2758 - y1_output_root_mean_squared_error: 0.3366 - y2_output_root_mean_squared_error: 0.5260 - val_loss: 0.7622 - val_y1_output_loss: 0.1980 - val_y2_output_loss: 0.5891 - val_y1_output_root_mean_squared_error: 0.4470 - val_y2_output_root_mean_squared_error: 0.7499
# Epoch 479/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3430 - y1_output_loss: 0.1047 - y2_output_loss: 0.2380 - y1_output_root_mean_squared_error: 0.3243 - y2_output_root_mean_squared_error: 0.4877 - val_loss: 0.6908 - val_y1_output_loss: 0.1547 - val_y2_output_loss: 0.5670 - val_y1_output_root_mean_squared_error: 0.3976 - val_y2_output_root_mean_squared_error: 0.7299
# Epoch 480/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.4114 - y1_output_loss: 0.1246 - y2_output_loss: 0.2843 - y1_output_root_mean_squared_error: 0.3537 - y2_output_root_mean_squared_error: 0.5351 - val_loss: 0.6508 - val_y1_output_loss: 0.2003 - val_y2_output_loss: 0.4658 - val_y1_output_root_mean_squared_error: 0.4516 - val_y2_output_root_mean_squared_error: 0.6685
# Epoch 481/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4868 - y1_output_loss: 0.1417 - y2_output_loss: 0.3432 - y1_output_root_mean_squared_error: 0.3776 - y2_output_root_mean_squared_error: 0.5867 - val_loss: 0.6836 - val_y1_output_loss: 0.1663 - val_y2_output_loss: 0.5337 - val_y1_output_root_mean_squared_error: 0.4149 - val_y2_output_root_mean_squared_error: 0.7151
# Epoch 482/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3012 - y1_output_loss: 0.1109 - y2_output_loss: 0.1911 - y1_output_root_mean_squared_error: 0.3342 - y2_output_root_mean_squared_error: 0.4353 - val_loss: 0.6211 - val_y1_output_loss: 0.1516 - val_y2_output_loss: 0.4980 - val_y1_output_root_mean_squared_error: 0.3935 - val_y2_output_root_mean_squared_error: 0.6828
# Epoch 483/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4814 - y1_output_loss: 0.1286 - y2_output_loss: 0.3539 - y1_output_root_mean_squared_error: 0.3593 - y2_output_root_mean_squared_error: 0.5936 - val_loss: 0.8775 - val_y1_output_loss: 0.1560 - val_y2_output_loss: 0.7730 - val_y1_output_root_mean_squared_error: 0.3979 - val_y2_output_root_mean_squared_error: 0.8480
# Epoch 484/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4726 - y1_output_loss: 0.1326 - y2_output_loss: 0.3402 - y1_output_root_mean_squared_error: 0.3655 - y2_output_root_mean_squared_error: 0.5823 - val_loss: 1.2267 - val_y1_output_loss: 0.2387 - val_y2_output_loss: 1.0154 - val_y1_output_root_mean_squared_error: 0.4868 - val_y2_output_root_mean_squared_error: 0.9949
# Epoch 485/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3505 - y1_output_loss: 0.1131 - y2_output_loss: 0.2397 - y1_output_root_mean_squared_error: 0.3366 - y2_output_root_mean_squared_error: 0.4870 - val_loss: 0.7748 - val_y1_output_loss: 0.2022 - val_y2_output_loss: 0.5760 - val_y1_output_root_mean_squared_error: 0.4556 - val_y2_output_root_mean_squared_error: 0.7531
# Epoch 486/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3970 - y1_output_loss: 0.1119 - y2_output_loss: 0.2842 - y1_output_root_mean_squared_error: 0.3352 - y2_output_root_mean_squared_error: 0.5335 - val_loss: 0.6059 - val_y1_output_loss: 0.1628 - val_y2_output_loss: 0.4766 - val_y1_output_root_mean_squared_error: 0.4055 - val_y2_output_root_mean_squared_error: 0.6644
# Epoch 487/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3694 - y1_output_loss: 0.1201 - y2_output_loss: 0.2478 - y1_output_root_mean_squared_error: 0.3457 - y2_output_root_mean_squared_error: 0.4999 - val_loss: 0.7006 - val_y1_output_loss: 0.1993 - val_y2_output_loss: 0.5639 - val_y1_output_root_mean_squared_error: 0.4391 - val_y2_output_root_mean_squared_error: 0.7126
# Epoch 488/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3244 - y1_output_loss: 0.1001 - y2_output_loss: 0.2273 - y1_output_root_mean_squared_error: 0.3155 - y2_output_root_mean_squared_error: 0.4742 - val_loss: 0.9588 - val_y1_output_loss: 0.1978 - val_y2_output_loss: 0.8041 - val_y1_output_root_mean_squared_error: 0.4487 - val_y2_output_root_mean_squared_error: 0.8703
# Epoch 489/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3521 - y1_output_loss: 0.1129 - y2_output_loss: 0.2475 - y1_output_root_mean_squared_error: 0.3290 - y2_output_root_mean_squared_error: 0.4938 - val_loss: 1.3557 - val_y1_output_loss: 0.1961 - val_y2_output_loss: 1.2549 - val_y1_output_root_mean_squared_error: 0.4389 - val_y2_output_root_mean_squared_error: 1.0785
# Epoch 490/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3736 - y1_output_loss: 0.1111 - y2_output_loss: 0.2615 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5114 - val_loss: 0.8324 - val_y1_output_loss: 0.1842 - val_y2_output_loss: 0.6394 - val_y1_output_root_mean_squared_error: 0.4319 - val_y2_output_root_mean_squared_error: 0.8037
# Epoch 491/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3797 - y1_output_loss: 0.1115 - y2_output_loss: 0.2711 - y1_output_root_mean_squared_error: 0.3332 - y2_output_root_mean_squared_error: 0.5183 - val_loss: 0.8413 - val_y1_output_loss: 0.2170 - val_y2_output_loss: 0.6353 - val_y1_output_root_mean_squared_error: 0.4676 - val_y2_output_root_mean_squared_error: 0.7891
# Epoch 492/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4671 - y1_output_loss: 0.1153 - y2_output_loss: 0.3482 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.5924 - val_loss: 0.5897 - val_y1_output_loss: 0.1378 - val_y2_output_loss: 0.4677 - val_y1_output_root_mean_squared_error: 0.3750 - val_y2_output_root_mean_squared_error: 0.6701
# Epoch 493/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4104 - y1_output_loss: 0.1143 - y2_output_loss: 0.2932 - y1_output_root_mean_squared_error: 0.3389 - y2_output_root_mean_squared_error: 0.5436 - val_loss: 0.6776 - val_y1_output_loss: 0.1454 - val_y2_output_loss: 0.5614 - val_y1_output_root_mean_squared_error: 0.3866 - val_y2_output_root_mean_squared_error: 0.7268
# Epoch 494/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3408 - y1_output_loss: 0.1042 - y2_output_loss: 0.2354 - y1_output_root_mean_squared_error: 0.3235 - y2_output_root_mean_squared_error: 0.4860 - val_loss: 0.7376 - val_y1_output_loss: 0.1550 - val_y2_output_loss: 0.6260 - val_y1_output_root_mean_squared_error: 0.3952 - val_y2_output_root_mean_squared_error: 0.7625
# Epoch 495/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.2866 - y1_output_loss: 0.0943 - y2_output_loss: 0.1934 - y1_output_root_mean_squared_error: 0.3083 - y2_output_root_mean_squared_error: 0.4377 - val_loss: 0.6927 - val_y1_output_loss: 0.1703 - val_y2_output_loss: 0.5194 - val_y1_output_root_mean_squared_error: 0.4167 - val_y2_output_root_mean_squared_error: 0.7205
# Epoch 496/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3480 - y1_output_loss: 0.1012 - y2_output_loss: 0.2512 - y1_output_root_mean_squared_error: 0.3152 - y2_output_root_mean_squared_error: 0.4987 - val_loss: 1.0315 - val_y1_output_loss: 0.2286 - val_y2_output_loss: 0.7845 - val_y1_output_root_mean_squared_error: 0.4819 - val_y2_output_root_mean_squared_error: 0.8940
# Epoch 497/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3761 - y1_output_loss: 0.1235 - y2_output_loss: 0.2516 - y1_output_root_mean_squared_error: 0.3509 - y2_output_root_mean_squared_error: 0.5030 - val_loss: 1.0844 - val_y1_output_loss: 0.4935 - val_y2_output_loss: 0.5814 - val_y1_output_root_mean_squared_error: 0.7016 - val_y2_output_root_mean_squared_error: 0.7695
# Epoch 498/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.4047 - y1_output_loss: 0.1295 - y2_output_loss: 0.2779 - y1_output_root_mean_squared_error: 0.3575 - y2_output_root_mean_squared_error: 0.5262 - val_loss: 1.0962 - val_y1_output_loss: 0.4017 - val_y2_output_loss: 0.6896 - val_y1_output_root_mean_squared_error: 0.6323 - val_y2_output_root_mean_squared_error: 0.8345
# Epoch 499/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.4225 - y1_output_loss: 0.1197 - y2_output_loss: 0.3014 - y1_output_root_mean_squared_error: 0.3465 - y2_output_root_mean_squared_error: 0.5499 - val_loss: 0.6084 - val_y1_output_loss: 0.1514 - val_y2_output_loss: 0.4740 - val_y1_output_root_mean_squared_error: 0.3954 - val_y2_output_root_mean_squared_error: 0.6723
# Epoch 500/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.4990 - y1_output_loss: 0.1234 - y2_output_loss: 0.3727 - y1_output_root_mean_squared_error: 0.3517 - y2_output_root_mean_squared_error: 0.6127 - val_loss: 0.7095 - val_y1_output_loss: 0.1837 - val_y2_output_loss: 0.5660 - val_y1_output_root_mean_squared_error: 0.4346 - val_y2_output_root_mean_squared_error: 0.7216

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.7095 - y1_output_loss: 0.1909 - y2_output_loss: 0.5277 - y1_output_root_mean_squared_error: 0.4346 - y2_output_root_mean_squared_error: 0.7216
# Loss = 0.709505194193357, Y1_loss = 0.19086453318595886, Y1_mse = 0.43457046151161194, Y2_loss = 0.5276851654052734, Y2_mse = 0.721563458442688

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
